# %%
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

import plotly.graph_objects as go

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed

import pandas as pd
import numpy as np

import tensorflow as tf

import matplotlib.pyplot as plt

import altair as alt
from altair import *

# %%
data_dir = "../../../data/"

# %%
def p2f(x):
    return float(x.strip('ppm'))

# %%
sensor = pd.read_csv("{}Campus Energy Centre_2.csv".format(data_dir))
sensor.columns = ["Timestamp", "value"]

# %%
sensor.head()
# Out:
#                                Timestamp  value
# 0  2021-03-31T23:45:00-07:00 Los_Angeles  29ppm
# 1  2021-04-01T00:00:00-07:00 Los_Angeles  29ppm
# 2  2021-04-01T00:15:00-07:00 Los_Angeles  29ppm
# 3  2021-04-01T00:30:00-07:00 Los_Angeles  29ppm
# 4  2021-04-01T00:45:00-07:00 Los_Angeles  29ppm

# %%
sensor.dtypes
# Out:
# Timestamp    object
# value        object
# dtype: object

# %%
sensor["value"].unique()
# Out:
# array(['29ppm', '1ppm', '23ppm', '25ppm', '27ppm', '24ppm', '26ppm',
#        '28ppm', '30ppm', '31ppm', '0ppm', '33ppm', '32ppm', '34ppm',
#        '35ppm', '22ppm', '21ppm', '20ppm', '19ppm', '18ppm', '38ppm',
#        '6ppm', '15ppm', '17ppm', '16ppm', '36ppm'], dtype=object)

# %%
# sensor["value"] = sensor["value"].fillna(method='ffill')
sensor = sensor.dropna()

# %%
sensor["value"] = sensor["value"].apply(p2f)

# %%
sensor.dtypes
# Out:
# Timestamp     object
# value        float64
# dtype: object

# %%
subset = sensor.tail(5000)
train = subset.head(4000)
test = subset.tail(1000)

# split = int(len(sensor)*0.8)
# train = sensor.head(split)
# test = sensor.tail(len(sensor)-split)

# %%
c1 = alt.Chart(sensor.tail(5000)).mark_line().encode(
    x='Timestamp',
    y='value'
)

alt.layer(c1).configure_view(
    stroke='transparent'
).configure_axis(
    domainWidth=0.8
).properties(
    width=1000,
    height=500
)
# Out:
# alt.LayerChart(...)

# %%
train["value"].unique()
# Out:
# array([26., 24., 25., 27., 28., 30., 29., 22., 23., 31., 32., 21., 20.,
#        19., 18., 34., 38., 35., 33.,  0.,  6., 15., 17., 16., 36.])

# %%
c1 = alt.Chart(train).mark_line().encode(
    x=alt.X('Timestamp', axis=alt.Axis(labels=False)),
    y=alt.Y("value", scale=Scale(domain=[0, 1]))
).properties(
    width=800,
    height=500
)

c2 = alt.Chart(test).mark_line().encode(
    x=alt.X('Timestamp', axis=alt.Axis(labels=False)),
    y=alt.Y("value", scale=Scale(domain=[0, 1]))
).properties(
    width=200,
    height=500
)

# c1 | c2

# %%
print(train.shape, test.shape)
# Out:
# (4000, 2) (1000, 2)

# %%
scaler = StandardScaler()
scaler = scaler.fit(train[['value']])

train['value'] = scaler.transform(train[['value']])
test['value'] = scaler.transform(test[['value']])
# Out:
# <ipython-input-102-1588914b5dea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['value'] = scaler.transform(train[['value']])
# <ipython-input-102-1588914b5dea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['value'] = scaler.transform(test[['value']])

# %%
TIME_STEPS=15

def create_sequences(X, y, time_steps=TIME_STEPS):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        Xs.append(X.iloc[i:(i+time_steps)].values)
        ys.append(y.iloc[i+time_steps])
    
    return np.array(Xs), np.array(ys)

X_train, y_train = create_sequences(train[['value']], train['value'])
X_test, y_test = create_sequences(test[['value']], test['value'])

print(f'Training shape: {X_train.shape}')
print(f'Testing shape: {X_test.shape}')
# Out:
# Training shape: (3985, 15, 1)
# Testing shape: (985, 15, 1)

# %%
# Architecture found on https://towardsdatascience.com/time-series-of-price-anomaly-detection-with-lstm-11a12ba4f6d9
model = Sequential()
model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(rate=0.2))
model.add(RepeatVector(X_train.shape[1]))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(rate=0.2))
model.add(TimeDistributed(Dense(X_train.shape[2])))
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 15, 128)           0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 15, 128)           131584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 128)           0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 15, 1)             129
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1,
                    callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min')], shuffle=False)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 5s 22ms/step - loss: 0.3546 - val_loss: 0.3172
# Epoch 2/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.2986 - val_loss: 0.3090
# Epoch 3/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.3311 - val_loss: 0.3118
# Epoch 4/100
# 113/113 [==============================] - 2s 17ms/step - loss: 0.2960 - val_loss: 0.3081
# Epoch 5/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.3075 - val_loss: 0.3076
# Epoch 6/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2950 - val_loss: 0.3087
# Epoch 7/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2851 - val_loss: 0.3045
# Epoch 8/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2803 - val_loss: 0.3034
# Epoch 9/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2834 - val_loss: 0.3026
# Epoch 10/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2731 - val_loss: 0.2973
# Epoch 11/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2728 - val_loss: 0.2973
# Epoch 12/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2827 - val_loss: 0.2956
# Epoch 13/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2889 - val_loss: 0.2992
# Epoch 14/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2701 - val_loss: 0.2902
# Epoch 15/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2678 - val_loss: 0.2899
# Epoch 16/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2668 - val_loss: 0.2878
# Epoch 17/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2788 - val_loss: 0.2902
# Epoch 18/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2781 - val_loss: 0.2895
# Epoch 19/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.3053 - val_loss: 0.2875
# Epoch 20/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2954 - val_loss: 0.2935
# Epoch 21/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2704 - val_loss: 0.2878
# Epoch 22/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2754 - val_loss: 0.2885
# Epoch 23/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2832 - val_loss: 0.2896
# Epoch 24/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2834 - val_loss: 0.2880
# Epoch 25/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2831 - val_loss: 0.2894
# Epoch 26/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2696 - val_loss: 0.2865
# Epoch 27/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2673 - val_loss: 0.2866
# Epoch 28/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2732 - val_loss: 0.2877
# Epoch 29/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2826 - val_loss: 0.2888
# Epoch 30/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.3012 - val_loss: 0.2891
# Epoch 31/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2891 - val_loss: 0.2902
# Epoch 32/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2716 - val_loss: 0.2868
# Epoch 33/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2650 - val_loss: 0.2837
# Epoch 34/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2801 - val_loss: 0.2873
# Epoch 35/100
# 113/113 [==============================] - 3s 24ms/step - loss: 0.2942 - val_loss: 0.2882
# Epoch 36/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2788 - val_loss: 0.2874
# Epoch 37/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2871 - val_loss: 0.2861
# Epoch 38/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2879 - val_loss: 0.2873
# Epoch 39/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2845 - val_loss: 0.2875
# Epoch 40/100
# 113/113 [==============================] - 3s 23ms/step - loss: 0.2721 - val_loss: 0.2840
# Epoch 41/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2661 - val_loss: 0.2835
# Epoch 42/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2760 - val_loss: 0.2870
# Epoch 43/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2840 - val_loss: 0.2869
# Epoch 44/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2829 - val_loss: 0.2851
# Epoch 45/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2790 - val_loss: 0.2840
# Epoch 46/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2723 - val_loss: 0.2856
# Epoch 47/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2712 - val_loss: 0.2877
# Epoch 48/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2728 - val_loss: 0.2857
# Epoch 49/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2714 - val_loss: 0.2849
# Epoch 50/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2645 - val_loss: 0.2820
# Epoch 51/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2763 - val_loss: 0.2863
# Epoch 52/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2862 - val_loss: 0.2892
# Epoch 53/100
# 113/113 [==============================] - 3s 22ms/step - loss: 0.2900 - val_loss: 0.2855
# Epoch 54/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2707 - val_loss: 0.2817
# Epoch 55/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2634 - val_loss: 0.2830
# Epoch 56/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2605 - val_loss: 0.2804
# Epoch 57/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2601 - val_loss: 0.2810
# Epoch 58/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2605 - val_loss: 0.2823
# Epoch 59/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2661 - val_loss: 0.2858
# Epoch 60/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2741 - val_loss: 0.2797
# Epoch 61/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2592 - val_loss: 0.2802
# Epoch 62/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2576 - val_loss: 0.2778
# Epoch 63/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2581 - val_loss: 0.2767
# Epoch 64/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2579 - val_loss: 0.2758
# Epoch 65/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2684 - val_loss: 0.2784
# Epoch 66/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2741 - val_loss: 0.2784
# Epoch 67/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2604 - val_loss: 0.2766
# Epoch 68/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2585 - val_loss: 0.2722
# Epoch 69/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2618 - val_loss: 0.2703
# Epoch 70/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2555 - val_loss: 0.2661
# Epoch 71/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2465 - val_loss: 0.2582
# Epoch 72/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2476 - val_loss: 0.2641
# Epoch 73/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2578 - val_loss: 0.2641
# Epoch 74/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2698 - val_loss: 0.2576
# Epoch 75/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2526 - val_loss: 0.2598
# Epoch 76/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2376 - val_loss: 0.2531
# Epoch 77/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2364 - val_loss: 0.2525
# Epoch 78/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2368 - val_loss: 0.2488
# Epoch 79/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2554 - val_loss: 0.2533
# Epoch 80/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2478 - val_loss: 0.2531
# Epoch 81/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2323 - val_loss: 0.2487
# Epoch 82/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2359 - val_loss: 0.2537
# Epoch 83/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2521 - val_loss: 0.2562
# Epoch 84/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2653 - val_loss: 0.2504
# Epoch 85/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2397 - val_loss: 0.2469
# Epoch 86/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2386 - val_loss: 0.2456
# Epoch 87/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2689 - val_loss: 0.2518
# Epoch 88/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2491 - val_loss: 0.2424
# Epoch 89/100
# 113/113 [==============================] - 2s 22ms/step - loss: 0.2544 - val_loss: 0.2495
# Epoch 90/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2553 - val_loss: 0.2490
# Epoch 91/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2434 - val_loss: 0.2440
# Epoch 92/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2304 - val_loss: 0.2419
# Epoch 93/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2256 - val_loss: 0.2411
# Epoch 94/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2263 - val_loss: 0.2427
# Epoch 95/100
# 113/113 [==============================] - 2s 18ms/step - loss: 0.2332 - val_loss: 0.2458
# Epoch 96/100
# 113/113 [==============================] - 2s 19ms/step - loss: 0.2378 - val_loss: 0.2418
# Epoch 97/100
# 113/113 [==============================] - 2s 21ms/step - loss: 0.2367 - val_loss: 0.2437
# Epoch 98/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2678 - val_loss: 0.2462
# Epoch 99/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2358 - val_loss: 0.2440
# Epoch 100/100
# 113/113 [==============================] - 2s 20ms/step - loss: 0.2345 - val_loss: 0.2402

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend();

# %%
model.evaluate(X_test, y_test)
# Out:
# 31/31 [==============================] - 0s 6ms/step - loss: 0.2212
# 0.221212238073349

# %%
X_train_pred = model.predict(X_train, verbose=0)
train_mae_loss = np.mean(np.abs(X_train_pred - X_train), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel('Train MAE loss')
plt.ylabel('Number of Samples');

# threshold = np.max(train_mae_loss) / 3.0
threshold = 1.5
print(f'Reconstruction error threshold: {threshold}')
# Out:
# Reconstruction error threshold: 1.5

# %%
X_test_pred = model.predict(X_test, verbose=0)
test_mae_loss = np.mean(np.abs(X_test_pred-X_test), axis=1)

plt.hist(test_mae_loss, bins=50)
plt.xlabel('Test MAE loss')
plt.ylabel('Number of samples');

# %%
test_score_df = pd.DataFrame(test[TIME_STEPS:])
test_score_df['loss'] = test_mae_loss
test_score_df['threshold'] = threshold
test_score_df['anomaly'] = test_score_df['loss'] > test_score_df['threshold']
test_score_df['value'] = test[TIME_STEPS:]['value']


plt.plot(test_score_df['threshold'], label='Threshold')
plt.plot(test_score_df['loss'], label='Validation loss')
plt.legend();

# %%
anomalies = test_score_df.loc[test_score_df['anomaly'] == True]
anomalies.shape
# Out:
# (10, 5)

# %%
c1 = alt.Chart(test_score_df.tail(1000)).mark_line().encode(
    x='Timestamp',
    y='value'
)

c2 = alt.Chart(anomalies.tail(1000)).mark_circle().encode(
    x='Timestamp',
    y='value'
)

# %%
alt.layer(c1, c2).configure_view(
    stroke='transparent'
).configure_axis(
    domainWidth=0.8
)
# Out:
# alt.LayerChart(...)
